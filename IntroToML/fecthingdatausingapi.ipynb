# %%
#id,title,release_date,voting_average

# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=b9b3ab88c3a6abbe9f74f97a8de4f139&language=en-US")

# %%
data = response.json()['results']

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    adult                     backdrop_path        genre_ids   id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]  278
# 1  False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg         [18, 80]  238
# 2  False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg         [18, 80]  240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]  424
# 4  False  /bxgTSUenZDHNFerQ1whRKplrMKF.jpg             [18]  389
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en     The Godfather Part II
# 3                en          Schindler's List
# 4                en              12 Angry Men
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     172.502
# 1  Spanning the years 1945 to 1955, a chronicle o...     161.181
# 2  In the continuing saga of the Corleone crime f...      94.195
# ...

# %%
df = df[['id','title','release_date','vote_average']]

# %%
df.head()
# Out:
#     id                     title release_date  vote_average
# 0  278  The Shawshank Redemption   1994-09-23         8.708
# 1  238             The Godfather   1972-03-14         8.689
# 2  240     The Godfather Part II   1974-12-20         8.600
# 3  424          Schindler's List   1993-12-15         8.567
# 4  389              12 Angry Men   1957-04-10         8.546

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
df.head()
# Out:
#     id                     title release_date  vote_average
# 0  278  The Shawshank Redemption   1994-09-23         8.708
# 1  238             The Godfather   1972-03-14         8.689
# 2  240     The Godfather Part II   1974-12-20         8.600
# 3  424          Schindler's List   1993-12-15         8.567
# 4  389              12 Angry Men   1957-04-10         8.546

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            20 non-null     int64
#  1   title         20 non-null     object
#  2   release_date  20 non-null     datetime64[ns]
#  3   vote_average  20 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 768.0+ bytes

# %%
df = pd.DataFrame()

# %%
for i in range(1,498):
    response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=b9b3ab88c3a6abbe9f74f97a8de4f139&language=en-US"+f'page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','release_date','vote_average']]
    df = pd.concat([df,temp_df],ignore_index=True)

# %%
df
# Out:
#           id                     title release_date  vote_average
# 0        278  The Shawshank Redemption   1994-09-23         8.708
# 1        238             The Godfather   1972-03-14         8.689
# 2        240     The Godfather Part II   1974-12-20         8.600
# 3        424          Schindler's List   1993-12-15         8.567
# 4        389              12 Angry Men   1957-04-10         8.546
# ...      ...                       ...          ...           ...
# 9935     346             Seven Samurai   1954-04-26         8.500
# 9936     769                GoodFellas   1990-09-12         8.458
# 9937   12477    Grave of the Fireflies   1988-04-16         8.453
# 9938  157336              Interstellar   2014-11-05         8.400
# 9939     637         Life Is Beautiful   1997-12-20         8.448
#
# [9940 rows x 4 columns]

# %%
df.shape
# Out:
# (9940, 4)

# %%
df.to_csv('./data/movie.csv')

# %%
df = pd.read_csv('./data/movie.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   id                     title release_date  vote_average
# 0           0  278  The Shawshank Redemption   1994-09-23         8.708
# 1           1  238             The Godfather   1972-03-14         8.689
# 2           2  240     The Godfather Part II   1974-12-20         8.600
# 3           3  424          Schindler's List   1993-12-15         8.567
# 4           4  389              12 Angry Men   1957-04-10         8.546

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#     id                     title release_date  vote_average
# 0  278  The Shawshank Redemption   1994-09-23         8.708
# 1  238             The Godfather   1972-03-14         8.689
# 2  240     The Godfather Part II   1974-12-20         8.600
# 3  424          Schindler's List   1993-12-15         8.567
# 4  389              12 Angry Men   1957-04-10         8.546
